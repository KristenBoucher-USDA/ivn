# %%
import re
import json
import csv
from collections import Counter
from pathlib import Path
from typing import List, Dict, Set

# %%
# Third-party imports
try:
    import openpyxl
except ImportError:
    print("Error: openpyxl is required. Install with: pip install openpyxl")
    exit(1)

try:
    import tkinter as tk
    from tkinter import filedialog, ttk, messagebox
except ImportError:
    print("Error: tkinter is required for file dialogs.")
    exit(1)

# %%
# ============================================================================
# STOPWORDS - Common words to filter out during keyword extraction
# ============================================================================
STOPWORDS = {
    'the', 'be', 'to', 'of', 'and', 'a', 'in', 'that', 'have', 'i',
    'it', 'for', 'not', 'on', 'with', 'he', 'as', 'you', 'do', 'at',
    'this', 'but', 'his', 'by', 'from', 'they', 'we', 'say', 'her', 'she',
    'or', 'an', 'will', 'my', 'one', 'all', 'would', 'there', 'their',
    'what', 'so', 'up', 'out', 'if', 'about', 'who', 'get', 'which', 'go',
    'me', 'when', 'make', 'can', 'like', 'time', 'no', 'just', 'him', 'know',
    'take', 'people', 'into', 'year', 'your', 'good', 'some', 'could', 'them',
    'see', 'other', 'than', 'then', 'now', 'look', 'only', 'come', 'its', 'over',
    'think', 'also', 'back', 'after', 'use', 'two', 'how', 'our', 'work', 'first',
    'well', 'way', 'even', 'new', 'want', 'because', 'any', 'these', 'give', 'day',
    'most', 'us', 'is', 'was', 'are', 'been', 'has', 'had', 'were', 'said', 'did',
    'having', 'may', 'should', 'must', 'shall', 'being', 'does', 'such', 'each',
    'through', 'where', 'both', 'those', 'during', 'before', 'herself', 'himself',
    'itself', 'between', 'under', 'above', 'below', 'within', 'without', 'against',    'none', 'more', 'very', 'still', 'here', 'too', 'own', 'same', 'been', 'being',
    'including', 'based', 'using', 'available', 'provides', 'provide', 'requires',
    'addresses', 'supports', 'enable', 'enables', 'meet', 'meets', 'needs',
    'dr', 'it'
}

# Words to exclude from acronym detection (common uppercase words)
ACRONYM_EXCLUDES = {
    'THE', 'AND', 'FOR', 'THIS', 'THAT', 'WITH', 'FROM', 'WILL', 'HAVE',
    'ARE', 'WAS', 'BEEN', 'HAS', 'HAD', 'ALL', 'NOT', 'BUT', 'CAN'
}


def select_xlsx_file() -> str:
    """
    Open a file dialog for the user to select an XLSX file.
    
    Returns:
        str: Path to the selected file, or empty string if cancelled.
    """
    root = tk.Tk()
    root.withdraw()  # Hide the main window
    root.attributes('-topmost', True)  # Bring dialog to front
    
    file_path = filedialog.askopenfilename(
        title="Select Excel File (.xlsx)",
        filetypes=[
            ("Excel files", "*.xlsx"),
            ("All files", "*.*")
        ]
    )
    
    root.destroy()
    return file_path


def get_workbook_tabs(file_path: str) -> List[str]:
    """
    Read an XLSX file and return a list of all worksheet tab names.
    
    Args:
        file_path: Path to the XLSX file.
        
    Returns:
        List of worksheet names.
    """
    workbook = openpyxl.load_workbook(file_path, read_only=True)
    tab_names = workbook.sheetnames
    workbook.close()
    return tab_names


def select_tab(tab_names: List[str]) -> str:
    """
    Display a dialog for the user to select which tab to process.
    
    Args:
        tab_names: List of available worksheet names.
        
    Returns:
        The selected tab name, or empty string if cancelled.
    """
    selected_tab = ""
    
    def on_select():
        nonlocal selected_tab
        selection = listbox.curselection()
        if selection:
            selected_tab = tab_names[selection[0]]
        root.destroy()
    
    def on_double_click(event):
        on_select()
    
    def on_cancel():
        root.destroy()
    
    root = tk.Tk()
    root.title("Select Worksheet Tab")
    root.geometry("400x300")
    root.attributes('-topmost', True)
    
    # Center the window
    root.update_idletasks()
    x = (root.winfo_screenwidth() // 2) - (400 // 2)
    y = (root.winfo_screenheight() // 2) - (300 // 2)
    root.geometry(f"400x300+{x}+{y}")
    
    # Label
    label = tk.Label(root, text="Select a worksheet tab to extract keywords from:", 
                     font=('Arial', 10))
    label.pack(pady=10)
    
    # Listbox with scrollbar
    frame = tk.Frame(root)
    frame.pack(fill=tk.BOTH, expand=True, padx=20, pady=5)
    
    scrollbar = tk.Scrollbar(frame)
    scrollbar.pack(side=tk.RIGHT, fill=tk.Y)
    
    listbox = tk.Listbox(frame, yscrollcommand=scrollbar.set, font=('Arial', 10),
                         selectmode=tk.SINGLE)
    for tab in tab_names:
        listbox.insert(tk.END, tab)
    listbox.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)
    listbox.bind('<Double-1>', on_double_click)
    
    scrollbar.config(command=listbox.yview)
    
    # Select first item by default
    if tab_names:
        listbox.selection_set(0)
    
    # Buttons
    button_frame = tk.Frame(root)
    button_frame.pack(pady=10)
    
    select_btn = tk.Button(button_frame, text="Select", command=on_select, width=10)
    select_btn.pack(side=tk.LEFT, padx=5)
    
    cancel_btn = tk.Button(button_frame, text="Cancel", command=on_cancel, width=10)
    cancel_btn.pack(side=tk.LEFT, padx=5)
    
    root.mainloop()
    
    return selected_tab


def normalize_apostrophes(text: str) -> str:
    """
    Replace Unicode apostrophe variants with plain ASCII apostrophe.
    
    This prevents encoding issues where characters like ʼ (modifier letter apostrophe)
    or ' (right single quotation mark) get corrupted in output.
    
    Args:
        text: Input text that may contain Unicode apostrophes.
        
    Returns:
        Text with all apostrophe variants replaced with plain apostrophe (').
    """
    # Unicode apostrophe and quote variants to normalize
    apostrophe_variants = [
        '\u02bc',  # ʼ - Modifier Letter Apostrophe
        '\u2019',  # ' - Right Single Quotation Mark
        '\u2018',  # ' - Left Single Quotation Mark
        '\u0060',  # ` - Grave Accent
        '\u00b4',  # ´ - Acute Accent
        '\u2032',  # ′ - Prime
        '\u2035',  # ‵ - Reversed Prime
    ]
    
    for variant in apostrophe_variants:
        text = text.replace(variant, "'")
    
    return text


def read_xlsx_tab(file_path: str, tab_name: str) -> tuple[List[str], List[str], List[Dict]]:
    """
    Read all text content from a specific worksheet tab.
    
    Args:
        file_path: Path to the XLSX file.
        tab_name: Name of the worksheet to read.
        
    Returns:
        Tuple of (headers, paragraphs, row_data):
        - headers: List of column headers from the first row
        - paragraphs: List of text paragraphs (combined text from each row)
        - row_data: List of dicts containing original column values for each row
    """
    workbook = openpyxl.load_workbook(file_path, read_only=True)
    worksheet = workbook[tab_name]
    
    headers = []
    paragraphs = []
    row_data = []
    
    for idx, row in enumerate(worksheet.iter_rows()):
        # First row contains headers
        if idx == 0:
            headers = [str(cell.value).strip() if cell.value is not None else f"Column{i+1}" 
                      for i, cell in enumerate(row)]
            continue
        
        row_text_parts = []
        row_values = {}
        
        for col_idx, cell in enumerate(row):
            if cell.value is not None:
                cell_text = str(cell.value).strip()
                # Normalize Unicode apostrophes to plain ASCII
                cell_text = normalize_apostrophes(cell_text)
                # Replace hard returns and tabs with single space in Component Description column
                if col_idx < len(headers) and 'Component Description' in headers[col_idx]:
                    cell_text = cell_text.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
                    # Normalize multiple spaces to single space
                    cell_text = ' '.join(cell_text.split())
                if cell_text:
                    row_text_parts.append(cell_text)
                    # Store original column value
                    if col_idx < len(headers):
                        row_values[headers[col_idx]] = cell_text
        
        # Combine all cells in a row into one paragraph
        if row_text_parts:
            row_text = ' '.join(row_text_parts)
            # Only include paragraphs with 50+ characters
            if len(row_text) >= 50:
                paragraphs.append(row_text)
                row_data.append(row_values)
    
    workbook.close()
    return headers, paragraphs, row_data


def clean_text_for_words(text: str) -> str:
    """
    Clean text for word extraction - convert to lowercase.
    
    Args:
        text: Raw text string.
        
    Returns:
        Cleaned lowercase text string.
    """
    text = text.lower()
    # Remove special characters but keep hyphens, spaces, and numbers
    text = re.sub(r'[^\w\s-]', ' ', text)
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    return text


def tokenize(text: str) -> List[str]:
    """
    Split text into words, filtering out short words (3 or fewer characters).
    
    Args:
        text: Cleaned text string.
        
    Returns:
        List of words.
    """
    words = text.split()
    # Filter out words with 3 or fewer characters
    return [word for word in words if len(word) > 3]


def extract_acronyms(text: str) -> List[str]:
    """
    Extract acronyms (all uppercase words 2+ chars) from original text.
    
    Args:
        text: Original text (not lowercased).
        
    Returns:
        List of unique acronyms found.
    """
    # Find all uppercase words (2+ chars) 
    acronym_pattern = r'\b[A-Z][A-Z0-9]{1,}(?:-[A-Z0-9]+)*\b'
    found = re.findall(acronym_pattern, text)
    
    # Filter out excluded common words and dedupe
    acronyms = []
    seen = set()
    for word in found:
        if word not in ACRONYM_EXCLUDES and word not in seen:
            acronyms.append(word)
            seen.add(word)
    
    return acronyms


def extract_capitalized_phrases(text: str) -> List[str]:
    """
    Extract meaningful capitalized phrases (proper nouns, titles, technical terms).
    
    Args:
        text: Original text (not lowercased).
        
    Returns:
        List of capitalized phrases found.
    """
    phrases = []
    
    # Pattern for capitalized multi-word phrases (2-5 words)
    # Matches: "Cloud Computing Policy", "Federal Information Technology"
    cap_phrase_pattern = r'\b([A-Z][a-z]+(?:\s+(?:[A-Z][a-z]+|[A-Z]+|of|and|the|for))+)\b'
    found_phrases = re.findall(cap_phrase_pattern, text)
    
    for phrase in found_phrases:
        # Clean up and validate
        phrase = phrase.strip()
        words = phrase.split()
        # Must have at least 2 words and start with capital
        if len(words) >= 2 and words[0][0].isupper():
            # Skip if it's just stopwords
            non_stop = [w for w in words if w.lower() not in {'of', 'and', 'the', 'for', 'a', 'an'}]
            if len(non_stop) >= 1:
                phrases.append(phrase)
    
    # Also extract patterns with parenthetical acronyms
    # Matches: "Enterprise Cloud Vendor Management (ECVM)"
    paren_pattern = r'([A-Z][a-z]+(?:\s+[A-Z][a-z]+)+)\s*\([A-Z]{2,}\)'
    paren_matches = re.findall(paren_pattern, text)
    phrases.extend(paren_matches)
    
    # Dedupe while preserving order
    seen = set()
    unique_phrases = []
    for p in phrases:
        p_lower = p.lower()
        if p_lower not in seen:
            unique_phrases.append(p)
            seen.add(p_lower)
    
    return unique_phrases


def extract_uncommon_words(paragraphs: List[str]) -> Set[str]:
    """
    Extract uncommon words that appear rarely across all paragraphs.
    
    Uncommon words are defined as words that:
    - Appear in only 1-2 paragraphs (rare across document)
    - Are longer than 5 characters (likely to be meaningful)
    - Are not stopwords
    - Appear at least once
    
    Args:
        paragraphs: List of all paragraph texts.
        
    Returns:
        Set of uncommon words found across the document.
    """
    # Track which paragraphs each word appears in
    word_paragraph_count: Dict[str, int] = {}
    
    for paragraph in paragraphs:
        cleaned = clean_text_for_words(paragraph)
        words = tokenize(cleaned)
        
        # Use a set to count each word only once per paragraph
        unique_words_in_para = set(words)
        
        for word in unique_words_in_para:
            if word not in STOPWORDS and len(word) > 5:
                word_paragraph_count[word] = word_paragraph_count.get(word, 0) + 1
    
    # Find words that appear in only 1-2 paragraphs (uncommon)
    total_paragraphs = len(paragraphs)
    threshold = min(2, max(1, total_paragraphs // 10))  # Max 2, or 10% of paragraphs
    
    uncommon = {
        word for word, count in word_paragraph_count.items()
        if count <= threshold
    }
    
    return uncommon


def extract_keywords(text: str, uncommon_words: Set[str] = None) -> Dict[str, List[str]]:
    """
    Extract uncommon keywords and key phrases from text.
    
    Preserves:
    - Acronyms in uppercase (USDA, GAO, FITARA)
    - Meaningful capitalized phrases (Cloud Computing, Service Level Agreement)
    - Important keywords by frequency
    
    Args:
        text: Raw paragraph text.
        uncommon_words: Set of uncommon words to prioritize (optional).
        
    Returns:
        Dictionary with 'keywords', 'phrases', and 'acronyms' lists.
    """
    # Extract acronyms from original text (before lowercasing)
    acronyms = extract_acronyms(text)
    
    # Extract capitalized phrases from original text
    cap_phrases = extract_capitalized_phrases(text)
    
    # Clean text for word frequency analysis
    cleaned = clean_text_for_words(text)
    words = tokenize(cleaned)
    
    # Count word frequencies (excluding stopwords)
    word_counts: Counter[str] = Counter()
    for word in words:
        if word not in STOPWORDS:
            word_counts[word] += 1
    
    # Get top keywords by frequency
    # Prioritize acronyms (add them first), then add frequent words
    keyword_set: Set[str] = set()
    keywords: List[str] = []
    
    # Add acronyms first (lowercased for consistency in keywords)
    for acr in acronyms[:3]:  # Max 3 acronyms in keywords
        acr_lower = acr.lower()
        if acr_lower not in keyword_set:
            keywords.append(acr_lower)
            keyword_set.add(acr_lower)
      # Add most common words
    for word, _ in word_counts.most_common(10):
        if word not in keyword_set and len(keywords) < 7:
            keywords.append(word)
            keyword_set.add(word)
    
    # Add uncommon words that appear in this paragraph
    if uncommon_words:
        paragraph_words = set(words)  # Words from current paragraph
        for word in paragraph_words:
            if (word in uncommon_words and 
                word not in keyword_set and 
                len(keywords) < 10):
                keywords.append(word)
                keyword_set.add(word)
    
    # Build phrases list
    # Start with meaningful capitalized phrases
    phrases: List[str] = []
    phrase_set: Set[str] = set()
    
    for phrase in cap_phrases[:5]:
        p_lower = phrase.lower()
        if p_lower not in phrase_set:
            phrases.append(phrase)
            phrase_set.add(p_lower)
    
    # Add n-gram phrases from lowercased text
    # Extract bigrams (2-word phrases)
    bigram_counts: Counter[str] = Counter()
    for i in range(len(words) - 1):
        if words[i] not in STOPWORDS or words[i + 1] not in STOPWORDS:
            bigram = f"{words[i]} {words[i + 1]}"
            bigram_counts[bigram] += 1
    
    # Extract trigrams (3-word phrases)  
    trigram_counts: Counter[str] = Counter()
    for i in range(len(words) - 2):
        # At least one word should not be a stopword
        if (words[i] not in STOPWORDS or 
            words[i + 1] not in STOPWORDS or 
            words[i + 2] not in STOPWORDS):
            trigram = f"{words[i]} {words[i + 1]} {words[i + 2]}"
            trigram_counts[trigram] += 1
    
    # Add top n-grams that appear more than once
    for phrase, count in trigram_counts.most_common():
        if count > 1 and phrase not in phrase_set and len(phrases) < 7:
            phrases.append(phrase)
            phrase_set.add(phrase)
    
    for phrase, count in bigram_counts.most_common():
        if count > 1 and phrase not in phrase_set and len(phrases) < 7:
            phrases.append(phrase)
            phrase_set.add(phrase)
    
    return {
        'keywords': keywords,
        'phrases': phrases,
        'acronyms': acronyms
    }


def process_paragraphs(paragraphs: List[str], row_data: List[Dict] = None) -> List[Dict]:
    """
    Process all paragraphs and extract keywords from each.
    
    Args:
        paragraphs: List of paragraph texts.
        row_data: Optional list of dicts containing original column values.
        
    Returns:
        List of result dictionaries.
    """
    results = []
    
    # Extract uncommon words from all paragraphs combined
    uncommon_words = extract_uncommon_words(paragraphs)
    
    for index, paragraph in enumerate(paragraphs):
        extracted = extract_keywords(paragraph, uncommon_words)
        result = {
            'rowNumber': index + 1,
            'text': paragraph,
            'keywords': extracted['keywords'],
            'phrases': extracted['phrases'],
            'acronyms': extracted['acronyms']
        }
        
        # Add original column data if available
        if row_data and index < len(row_data):
            result['original_columns'] = row_data[index]
        
        results.append(result)
    
    return results


def display_results(results: List[Dict]) -> None:
    """
    Display extraction results in the console.
    
    Args:
        results: List of result dictionaries.
    """
    print("\n" + "=" * 80)
    print(f"KEYWORD EXTRACTION RESULTS - {len(results)} paragraphs processed")
    print("=" * 80)
    
    for result in results:
        print(f"\n--- Paragraph {result['rowNumber']} ---")
        
        # Truncate text to 300 characters for display
        text_preview = result['text'][:300]
        if len(result['text']) > 300:
            text_preview += "..."
        print(f"Text: {text_preview}")
        
        print(f"Keywords: {', '.join(result['keywords']) if result['keywords'] else '(none)'}")
        print(f"Phrases: {', '.join(result['phrases']) if result['phrases'] else '(none)'}")
        print(f"Acronyms: {', '.join(result['acronyms']) if result['acronyms'] else '(none)'}")
    
    print("\n" + "=" * 80)


def export_csv(results: List[Dict], output_path: str, headers: List[str] = None) -> None:
    """
    Export results to a CSV file.
    
    Args:
        results: List of result dictionaries.
        output_path: Path for the output CSV file.
        headers: Optional list of original column headers from Excel file.
    """
    with open(output_path, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile, quoting=csv.QUOTE_ALL)
        
        # Build header row
        if headers and len(results) > 0 and 'original_columns' in results[0]:
            # Include original columns plus Keywords and Key Phrases
            header_row = ['Row'] + headers + ['Keywords', 'Key Phrases']
        else:
            # Fallback to simple format
            header_row = ['Row', 'Paragraph Text', 'Keywords', 'Key Phrases']
        
        writer.writerow(header_row)
        
        # Write data rows
        for result in results:
            # Combine acronyms with keywords for output
            all_keywords = result['acronyms'] + result['keywords']
            # Dedupe while preserving order
            seen = set()
            unique_keywords = []
            for kw in all_keywords:
                kw_lower = kw.lower()
                if kw_lower not in seen:
                    unique_keywords.append(kw)
                    seen.add(kw_lower)
            
            # Build row data
            if 'original_columns' in result and headers:
                # Include original column values
                row_data = [result['rowNumber']]
                for header in headers:
                    row_data.append(result['original_columns'].get(header, ''))
                row_data.extend([
                    ', '.join(unique_keywords),
                    ', '.join(result['phrases'])
                ])
            else:
                # Fallback to simple format
                row_data = [
                    result['rowNumber'],
                    result['text'],
                    ', '.join(unique_keywords),
                    ', '.join(result['phrases'])
                ]
            
            writer.writerow(row_data)
    
    print(f"CSV exported to: {output_path}")


def export_json(results: List[Dict], output_path: str) -> None:
    """
    Export results to a JSON file.
    
    Args:
        results: List of result dictionaries.
        output_path: Path for the output JSON file.
    """
    with open(output_path, 'w', encoding='utf-8') as jsonfile:
        json.dump(results, jsonfile, indent=2, ensure_ascii=False)
    
    print(f"JSON exported to: {output_path}")


def main():
    """Main entry point for the keyword extractor."""
    print("\n" + "=" * 80)
    print("IVN KEYWORD EXTRACTOR")
    print("=" * 80)
    
    # Step 1: Prompt user to select XLSX file
    print("\nStep 1: Select an Excel (.xlsx) file...")
    file_path = select_xlsx_file()
    
    if not file_path:
        print("No file selected. Exiting.")
        return
    
    print(f"Selected file: {file_path}")
    
    # Validate file extension
    if not file_path.lower().endswith('.xlsx'):
        print("Error: Please select a valid .xlsx file.")
        return
    
    # Step 2: Get list of tabs in the workbook
    print("\nStep 2: Reading workbook tabs...")
    try:
        tab_names = get_workbook_tabs(file_path)
    except Exception as e:
        print(f"Error reading workbook: {e}")
        return
    
    if not tab_names:
        print("Error: No worksheets found in the workbook.")
        return
    
    print(f"Found {len(tab_names)} tab(s): {', '.join(tab_names)}")
    
    # Step 3: Prompt user to select which tab to use
    print("\nStep 3: Select a worksheet tab...")
    selected_tab = select_tab(tab_names)
    
    if not selected_tab:
        print("No tab selected. Exiting.")
        return
    
    print(f"Selected tab: {selected_tab}")
    
    # Step 4: Read content from selected tab
    print("\nStep 4: Extracting text from worksheet...")
    try:
        headers, paragraphs, row_data = read_xlsx_tab(file_path, selected_tab)
    except Exception as e:
        print(f"Error reading worksheet: {e}")
        return
    
    if not paragraphs:
        print("No paragraphs found (minimum 50 characters per row).")
        return
    
    print(f"Found {len(paragraphs)} paragraph(s) to process.")
    
    # Step 5: Extract keywords from each paragraph
    print("\nStep 5: Extracting keywords and phrases...")
    results = process_paragraphs(paragraphs, row_data)
    
    # Step 6: Display results
    display_results(results)
    
    # Step 7: Export results
    base_path = Path(file_path).parent
    base_name = Path(file_path).stem
    
    csv_path = base_path / f"{base_name}_keywords.csv"
    json_path = base_path / f"{base_name}_keywords.json"
    
    print("\nStep 6: Exporting results...")
    export_csv(results, str(csv_path), headers)
    export_json(results, str(json_path))
    
    print("\n" + "=" * 80)
    print("EXTRACTION COMPLETE!")
    print("=" * 80)
    
    # Show completion message
    root = tk.Tk()
    root.withdraw()
    messagebox.showinfo(
        "Extraction Complete",
        f"Successfully extracted keywords from {len(results)} paragraphs.\n\n"
        f"CSV saved to:\n{csv_path}\n\n"
        f"JSON saved to:\n{json_path}"
    )
    root.destroy()


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# IVN KEYWORD EXTRACTOR
# ================================================================================
#
# Step 1: Select an Excel (.xlsx) file...
# Selected file: C:/Users/Kristen.Boucher/OneDrive - USDA/Desktop/Data Analysis/IVN/ivn/ivntest.xlsx
#
# Step 2: Reading workbook tabs...
# Found 15 tab(s): Dataset, Sources, Components, Alignments, Description Similarity, IVN-keyword-crosswalk, recent-alignments, Nonaligned-Edge-Cases, Sheet1, ToBeCrosswalked, Crosswalk-Backlog, Data Dictionary, unaligned_components_with_commo, Normalization, backup
#
# Step 3: Select a worksheet tab...
# Selected tab: Components
#
# Step 4: Extracting text from worksheet...
# Found 5182 paragraph(s) to process.
#
# Step 5: Extracting keywords and phrases...
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Acronyms: (none)
#
# --- Paragraph 4362 ---
# Text: FSIS Dir 3410.2: POST OFFICE BOX RENTALS - REVISION 3 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5100.3 Revision 3 2/16/17 DISTRIBUTION: Electronic OPI: OPPD ADMINISTRATIVE ENFORCEMENT ACTION DECISION -MAKING AND METHODOLOGY CHAPTER I – G...
# Keywords: fsis, post, office, enforcement, establishment, actions, verification
# Phrases: Electronic OPI, The Agency, District Office, Rules of Practice, Federal Meat Inspection Act, fsis directive 8010, corrective actions preventive
# Acronyms: FSIS, POST, OFFICE, BOX, RENTALS, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, DISTRIBUTION, OPI, OPPD, ADMINISTRATIVE, ENFORCEMENT, ACTION, DECISION, MAKING, METHODOLOGY, CHAPTER, GENERAL, PURPOSE, DO, ROP, CFR, FMIA, PPIA, HMSA, EIAO, PHV, DM, DDM, DVMS, II, SIGNIFICANT, CHANGES, AER, PHIS, III, CANCELLATION, IV, BACKGROUND, OFO, NOS, NOIE, HACCP, ACTIONS, FLS, IPP, FIELD, PERSONNEL, RESPONSIBILITIES, FSA, DCS, INVESTIGATION, ANALYSIS, OFFICER, PHRE, SUPERVISORY, NFORCEMENT, INVESTIGATIONS, SEIAO, DISTRICT, CASE, SPECIALIST, NOTE, XI, PDF, JPEG, PNG, TIFF, DOC, DOCX, OIEA, ELD, CID, VI, DEVELOPMENT, WORK, FLOW, IIC, NROS, LM, STEC, ANET, VII, EARO, HHEC, OPHS, VIII, RELATED, TO, HUMANE, HANDLING, MOI, IX, STATUTORY, AUTHORITY, EXAMINE, FACILITIES, COPY, RECORDS, SUPPORTING, REFERRALS, SOP, SPS, USC, RIMS, VERIFICATION, PLAN, DESIGN, EXECUTION
#
# --- Paragraph 4363 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5100.3.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5100.3.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4364 ---
# Text: FSIS Dir 3410.3: REIMBURSEMENT PROCEDURES FOR INSPECTION EXPENDITURES - REVISION 6 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5100.4 Rev. 1 5/22/15 ENFORCEMENT, INVESTIGATIONS AND ANALYSIS OFFICER (EIAO) PUBLIC HEALTH RISK EVALUATION (PHR...
# Keywords: fsis, reimbursement, procedures, phre, eiao, directive, establishment
# Phrases: Implementation of, Public Health Risk Evaluation, Analysis Officer, Public Health Veterinarian, Public Health Information System, public health risk, fsis directive 5100
# Acronyms: FSIS, REIMBURSEMENT, PROCEDURES, INSPECTION, EXPENDITURES, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, SERVICE, WASHINGTON, DC, DIRECTIVE, ENFORCEMENT, INVESTIGATIONS, ANALYSIS, OFFICER, EIAO, PUBLIC, HEALTH, RISK, EVALUATION, PHRE, METHODOLOGY, FSA, PHIS, PURPOSE, PHV, KEY, POINTS, II, CANCELLATION, III, BACKGROUND, DO, ODIFP, EMC, IIT, DISTRIBUTION, OPI, OPPD, IV, INTRODUCTION, IPP, FLS, VII, DM, AER, SCHEDULING, NR, PFGE, TABLE, OPHS, AES, OIEA, OFO, RMTAS, STEC, AMS, DAIS, RTE, PR, HACCP, LIMS, CCMS, PERFORMING, SEIAO, MOI, NOIE, NOS, NROS, NOSA, ROSA, LOW, DOCUMENTING, IVT, VIII, DATA, IX, QUESTIONS, RIMS, NOTE
#
# --- Paragraph 4365 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5100.4.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5100.4.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4366 ---
# Text: FSIS Dir 3410.4: PROMPT PAYMENT OF BILLS - REVISION 1 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5100.5 9/25/19 PUBLIC HEALTH REGULATIONS AND FSIS RESPONSE TO ELEVATED PUBLIC HEALTH REGULATION NONCOMPLIANCE RATES I. PURPOSE This directive...
# Keywords: fsis, prompt, payment, noncompliance, establishment, phre, public
# Phrases: Public Health Regulations, Frontline Supervisors, Public Health Information System, Early Warning Alerts, District Office, early warning alert, public health related
# Acronyms: FSIS, PROMPT, PAYMENT, OF, BILLS, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, PUBLIC, HEALTH, REGULATIONS, RESPONSE, TO, ELEVATED, REGULATION, NONCOMPLIANCE, RATES, PURPOSE, PHR, IPP, PHIS, DO, PHRE, FSA, KEY, POINTS, EIAO, II, BACKGROUND, OPARM, DISTRIBUTION, OPI, OPPD, O157, H7, STEC, SOP, HACCP, SPS, III, ANNUAL, CUT, SCHEDULING, EARLY, WARNING, ALERTS, IV, HRE, SCHEDULI, NG, VI, PH, VII, HR, LERT, PP, OTE, FLS, VIII, DATA, ANALYSIS, IX, QUESTIONS, NOTE, ID
#
# --- Paragraph 4367 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5100.5.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5100.5.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4368 ---
# Text: FSIS Dir 3410.6: REIMBURSABLE CHARGES FUNDED BY MISSION ASSIGNMENTS 5110.2REV1Crss-UtilofPGrdrs&Insps41392 REVISION 01 04/13/92 OPI: IO - Resource Management Staff CROSS-UTILIZATION OF POULTRY GRADERS AND FOOD INSPECTORS I. PURPOSE This directive describes the policy concerning cross-utilization of ...
# Keywords: fsis, reimbursable, charges, poultry, form, office, inspection
# Phrases: Resource Management Staff CROSS, Poultry Division and FSIS, Budget and Finance Division, Agricultural Marketing Service IO Inspection Operations, International Programs, fsis form 5110-1, regional office administrative
# Acronyms: FSIS, REIMBURSABLE, CHARGES, FUNDED, BY, MISSION, ASSIGNMENTS, REVISION, OPI, IO, CROSS-UTILIZATION, OF, POULTRY, GRADERS, FOOD, INSPECTORS, PURPOSE, AMS, IP, II, CANCELLATION, III, REASON, REISSUANCE, MP-11, IV, FORMS, ABBREVIATIONS, NFC, AD-742, PY-101, POLICY, VI, AUTHORIZED, VII, RESPONSIBILITY, VIII, AUTHORIZATION, CARD, CONTINUING, TEMPORARY, INSPECTOR, IX, RECORDING, HOURS, PREPARING, BILLING, APPROVED, USDA, SW, DC, ATTACHMENT
#
# --- Paragraph 4369 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5110.2.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5110.2.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4370 ---
# Text: FSIS Dir 3500.2: ACCOUNTING FOR FUNDS AND PROPERTY CHARGED TO SEPARATING EMPLOYEES 5110.3REV1Crss-UtilofMGrdrs&Insps41392 REVISION 01 04/13/92 OPI: IO - Resource Management Staff CROSS-UTILIZATION OF MEAT GRADERS AND FOOD INSPECTORS I. PURPOSE This directive describes the policy concerning the cross...
# Keywords: fsis, accounting, funds, meat, office, inspection, grading, checkloading, 3rev1crss-utilofmgrdrs, adiministrative
# Phrases: Resource Management Staff CROSS, Division and FSIS, Budget and Finance Division, Agricultural Marketing Service IO Inspection Operations, International Programs, fsis form 5110-1, meat grading certification
# Acronyms: FSIS, ACCOUNTING, FUNDS, PROPERTY, CHARGED, TO, SEPARATING, EMPLOYEES, REVISION, OPI, IO, CROSS-UTILIZATION, OF, MEAT, GRADERS, FOOD, INSPECTORS, PURPOSE, AMS, LS, IP, II, CANCELLATION, III, REASON, REISSUANCE, MP-11, IV, FORMS, ABBREVIATIONS, NFC, AD-742, LS-58, POLICY, VI, AUTHORIZED, VII, COORDINATION, VIII, AUTHORIZATION, CARD, CONTINUING, TEMPORARY, INSPECTOR, IX, TRAINING, COSTS, RECORDING, GRADING, INSPECTION, HOURS, PREPARING, BILLING, USDA, SW, DC, APPROVED, BY, ATTACHMENT
#
# --- Paragraph 4371 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5110.3.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5110.3.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4372 ---
# Text: FSIS Dir 3700.1: COLLECTING DEBTS - REVISION 2 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5220.1 Rev. 1 10/24 /22 GRANT OF INSPECTION MANAGEMENT I.PU RPO SE A.T his directive provides instructions on how to manage a Federal grant of inspe...
# Keywords: fsis, collecting, debts, inspection, establishment, form, applicant
# Phrases: Information System, Office of Field Operations, District Managers, Grant Curators, Enforcement and Audit, fsis form 5200-, official import inspection
# Acronyms: FSIS, COLLECTING, DEBTS, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, GRANT, MANAGEMENT, PU, RPO, SE, GOI, PHIS, OFO, FLS, OIEA, LEPS, EOS, FR, FSI, OTE, KEY, POINTS, PHI, EPS, GO, II, CANCE, LLATIO, SIS, DISTRIBUTION, OPI, OPPD, III, GC, RESPONSIBILITIES, GRANTING, NEW, ESTABLISHMENTS, OFFICIAL, IMPORT, CFR, ID, HACCP, IV, PROCESSING, APPLICATIONS, CHANGES, UPDATES, DO, DBA, DM, EO, LE, PS, VI, ESPONSIBILITIES, FMD, APHIS, USDA, NOTE, VII, RESPONSIBILITI, ES, OIE, DVMS, MOI, IIC, IPP, HAV, HA, CCP, VIII, REQUESTS, CHANGE, IN, APPROVED, WORK, SCHEDULES, IX, ESTABLISHMENT, VOLUNTARY, SUSPENSION, WITHDRAWALS, XI, WITHDRAWAL, XII, QUESTIONS
#
# --- Paragraph 4373 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5220.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5220.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4374 ---
# Text: FSIS Dir 3720.1: FEDERAL TORT CLAIMS - REVISION 4 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC 5220.3 10/8/15 FSIS DIRECTIVE Rev. 1 ISSUANCE OF A 10 -DAY LETTER FOR INACTIVE OPERATIONS I. PURPOSE This directive outlines the actions that a District Manager...
# Keywords: fsis, federal, tort, establishment, plant, inspection, letter
# Phrases: District Manager, Food and Drug Administration, District Office, Public Health Information System, Issuance of, within business days, business days from
# Acronyms: FSIS, FEDERAL, TORT, CLAIMS, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, ISSUANCE, DAY, LETTER, INACTIVE, OPERATIONS, PURPOSE, DM, DO, PHIS, II, CANCELLATION, III, BACKGROUND, IPP, NOTE, DISTRIBUTION, OPI, OPPD, IV, PROCEDURES, COMMUNICATING, ESTABLISHMENT, PLANTS, UPS, HACCP, IIC, FLS, DDM, ACTIONS, TO, BE, TAKEN, BASED, ON, ESTABLI, SHMENT, OR, PLANT, RESPONSE, VI, UPDATING, QUESTIONS, USDA, DRAFT, EXAMPLE, CERTIFIED, RETURN, RECEIPT, REQUESTED, SUBJECT, SOP
#
# --- Paragraph 4375 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5220.3.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5220.3.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4376 ---
# Text: FSIS Dir 3730.1: RECOVERY OF EMPLOYEE INDEBTEDNESS UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5300.1 10/19/16 Revision 1 MANAGING THE ESTABLISHMENT PROFILE IN THE PUBLIC HEALTH INFORMATION SYSTEM DO NOT IMPLEMENT THIS DIRECTIVE UNTIL MOND...
# Keywords: fsis, recovery, of, establishment, information, product, profile
# Phrases: Public Health Information System, Managing the Establishment Profile, Chapter II, Section VIII, Product Category List, establishment task list, haccp systems information
# Acronyms: FSIS, RECOVERY, OF, EMPLOYEE, INDEBTEDNESS, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, MANAGING, ESTABLISHMENT, PROFILE, IN, PUBLIC, HEALTH, INFORMATION, SYSTEM, DO, IMPLEMENT, UNTIL, MONDAY, NOVEMBER, CHAPTER, GENERAL, PURPOSE, IPP, PHIS, II, CANCELLATION, III, SIGNIFICANT, CHANGES, VIII, RTE, NRTE, DISTRIBUTION, OPI, OPPD, IV, ACKGRO, UND, HIS, IT, OW, TO, ACCESS, PHI, ID, PIN, PH, IS, INSPECTOR, HOMEPA, GE, VII, EST, ABLISHMENT, PROFI, LE, HACCP, PP, OTE, HOW, CREATE, AN, GC, FLS, EIAO, IX, RESPONSIBLIT, IES, PERFORMING, TASK, IIC, ESTABLISHMENTS, VI, CONTACTS, NOTE, GM, PO, APHIS, MOU, FDA, AMS, CFR, DBA, LIST, SYSTEMS, SLAUGHTER, EXAMPLE, EXAM, PLE, PRODUCT, PRODUCTION, VOLUME, ONLY
#
# --- Paragraph 4377 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5300.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5300.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4378 ---
# Text: FSIS Dir 3730.2: WAIVER OF CLAIMS AGAINST EMPLOYEES ARISING FROM ERRONEOUS PAYMENTS OF PAY AND ALLOWANCES - REVISION 3 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5420.1 Rev. 1 1 9/ 26/23 FOOD DEFENSE TASKS AND THREAT NOTIFICATION RESPONSE...
# Keywords: fsis, waiver, of, food, defense, establishment, task
# Phrases: Office of Data Integration and Food Protection, Office of Management, Significant Incident Preparedness and Resp, Food Defense Memorandum of Interview, Food Defense Verification Tasks and Threat Notification Response Procedures for the Office of Field Operations, food defense practices, food defense task
# Acronyms: FSIS, WAIVER, OF, CLAIMS, AGAINST, EMPLOYEES, ARISING, ERRONEOUS, PAYMENTS, PAY, ALLOWANCES, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, DEFENSE, TASKS, THREAT, NOTIFICATION, RESPONSE, PROCEDURES, OFFICE, FIELD, OPERATIONS, PURPOSE, IPP, ODIFP, OM, SIPRS, MOI, II, CANCELLATION, III, BACKGROUND, FDP, DISTRIBUTION, OPI, OPPD, IV, INTELLIGENCE, COMMUNITY, OFO, OIEA, OPACE, OIC, OPHS, AA, DAA, PERFO, RMING, IN, PHIS, FLS, NR, SIS, FIRST, FDA, AL, ERT, FD, SCADA, NIST, US-CERT, IIC, VI, OBSERVE, DOCUMENT, VULNERABILITIES, OIA, HACCP, SOP, VII, FO, OD, FACILITIES, PAYING, FEES, VOLUNTARY, CFR, VIII, SUPERVISORY, RESPONSIBILITIES, IPPS, IX, DATA, ANALYSIS, OPARM, QUESTIONS
#
# --- Paragraph 4379 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5420.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5420.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4380 ---
# Text: FSIS Dir 3800.2: REIMBURSEMENT FOR USE OF PRIVATELY OWNED VEHICLES - REVISION 3: AMENDMENT 5 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5420.3 Rev. 7 2/6/14 FOOD DEFENSE SURVEILLANCE PROCEDURES AND NATIONAL TERRORISM ADVISORY SYSTEM ALERT...
# Keywords: fsis, reimbursement, use, food, personnel, defense, surveillance
# Phrases: Food Defense Surveillance Procedures, Food Safety and Inspection Service, Office of Investigation, Enforcement and Audit, Compliance and Investigations Division, food defense surveillance, defense surveillance procedures
# Acronyms: FSIS, REIMBURSEMENT, USE, OF, PRIVATELY, OWNED, VEHICLES, REVISION, AMENDMENT, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, DEFENSE, SURVEILLANCE, PROCEDURES, NATIONAL, TERRORISM, ADVISORY, SYSTEM, ALERT, RESPONSE, OFFICE, INVESTIGATION, ENFORCEMENT, AUDIT, PURPOSE, OIEA, CID, DHS, NTAS, AA, EMC, KEY, POINTS, FDP, II, CANCELLATION, III, BACKGROUND, DISTRIBUTION, OPI, OPPD, IV, NOTIFICATION, ODIFP, OPACE, ACTIVITIES, VII, OPHS, FERN, OFO, VI, FUNCTIONAL, PLAN, SURVEILLANC, NOTE, VIII, PROCEDURE, DOCUMENTATION, ICS, IX, ADULTERATED, PRODUCT, OR, POSSIBLE, TAMPERING, IR, OIG, DATA, ANALYSIS, XI, QUESTIONS
#
# --- Paragraph 4381 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5420.3.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5420.3.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4382 ---
# Text: FSIS Dir 3805.3: CONDITIONS FOR REIMBURSING TRAVEL EXPENSES OF NONGOVERNMENT TRAVELER - REVISION 1 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5500.2 Revision 7 11/8/18 SIGNIFICANT INCIDENT RESPONSE I. PURPOSE This directive outlines the p...
# Keywords: fsis, conditions, reimbursing, designee, incident, fims, information, prepopulate, -occupied, cid-director
# Phrases: Emergency Management Committee, Defines the EMC and, Incident Management System, Significant Incident Response, Homeland Security Threat Condition Response, fsis personnel responsible, automated employee tracking
# Acronyms: FSIS, CONDITIONS, REIMBURSING, TRAVEL, EXPENSES, OF, NONGOVERNMENT, TRAVELER, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, SIGNIFICANT, INCIDENT, RESPONSE, PURPOSE, EMC, IR, KEY, POINTS, FIMS, CANCELLATION, DISTRIBUTION, OPI, OPPD, III, BACKGROUND, OA, COO, ESF, NRCC, IV, NOTIFICATION, THREAT, INTELLIGENCE, COMMUNITY, MC, OFO, OIEA, OPACE, OPHS, IPP, MOI, PERSONNEL, RESPONSIBILITIES, REPORTING, SIPRS, CID, AES, FERN, NBIC, VIII, VI, COMPLETING, AN, REPORT, FIM, SIPR, VII, OR, MAIL, SYSTEM, OUTAGE, AA, ERI, SEDO, REVIEWING, ALERTING, ACTIVATING, NOTE, USDA, OHS, IX, IC, WORK, EM, XI, FORM, IMPACT, INCIDENTS, ON, ESTABLISHMENTS, INCLUDING, IMPORT, WAREHOUSES, AUTOMATED, EMPLOYEE, TRACKING, SHEET, XII, XIII, QUESTIONS, CIO, CFO, OIC, DO, MCAD, MPI, FSES, ECIMS, PAS, FOIAS, WDCS, CPAS, DM, DDM, CCMS, CDC, OEE, OEED, OM, ASD, SPSB, SPS
#
# --- Paragraph 4383 ---
# Text: FSIS Dir 3820.1: RELOCATION FOR TRANSFERRING EMPLOYEES - REVISION 4 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5500.3 7/19/2006 INCIDENT INVESTIGATION TEAM REVIEWS I. PURPOSE This directive defines Incident Invest igation Teams (IITs), ex...
# Keywords: fsis, relocation, transferring, establishment, team, review, report
# Phrases: Incident Invest, Food Safety and Inspection Service, The FSIS Emergency Management Co, Inspection Offices, Plant OPI, fsis 3820 relocation, 3820 relocation transferring
# Acronyms: FSIS, RELOCATION, TRANSFERRING, EMPLOYEES, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, INCIDENT, INVESTIGATION, TEAM, REVIEWS, PURPOSE, II, CANCELLATION, III, RESERVED, IV, REFERENCES, CFR, BACKGROUND, EMC, IIT, DISTRIBUTION, OPI, OPPED, TRA, ABB, TSC, VI, O157, H7, AA, OIG, NOTE, TL, DO, OPEER, CID, HACCP
#
# --- Paragraph 4384 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5500.3.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5500.3.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4385 ---
# Text: FSIS Dir 3830.2: GOVERNMENT TRAVEL CHARGE CARD PROGRAM - REVISION 5 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5500.4 Revision 1 4/4/24 PRODUCTS INTENTIONALLY ADULTERATED WITH THREAT AGENTS I. PURPOSE This directive addresses instances in...
# Keywords: fsis, government, travel, product, intentionally, adulterated, facility
# Phrases: Emergency Management Committee, Products Intentionally Adulterated, Threat Agents, Environmental Protection Agency, Significant Incident Response, intentionally adulterated product, through supervisory channels
# Acronyms: FSIS, GOVERNMENT, TRAVEL, CHARGE, CARD, PROGRAM, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, PRODUCTS, INTENTIONALLY, ADULTERATED, THREAT, AGENTS, PURPOSE, EMC, URL, II, CANCELLATION, III, BACKGROUND, IV, INVESTIGATION, IC, OIEA, OIG, FBI, DHS, DISTRIBUTION, OPI, OPPD, CONTROL, PRODUCT, IPP, VI, DISPOSAL, VII, QUESTIONS
#
# --- Paragraph 4386 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5500.4.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5500.4.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4387 ---
# Text: FSIS Dir 3850.1: CONFERENCE PLANNING AND REPORTING REQUIREMENTS ________________________ _____________________ _________________________ UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5600.1 6/19/09 CLEARANCE AND POSTING OF DATA ANALYSES FOR ...
# Keywords: fsis, conference, planning, data, analysis, daig, document
# Phrases: Food Safety and Inspection Service, Internet Web, An Agency, Office of Public Affairs and Consumer Education, Web Services Staff, determine where post, site once representative
# Acronyms: FSIS, CONFERENCE, PLANNING, REPORTING, REQUIREMENTS, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, CLEARANCE, POSTING, DATA, ANALYSES, INTERNET, WEB, SITE, PURPOSE, OPACE, WSS, II, RESERVED, III, IV, REFERENCES, USDA, BACKGROUND, DAIG, OMB, DISTRIBUTION, OPI, OPPD, VI, PROCESS, FS, IS, AA, OFO, CPA, OPHS
#
# --- Paragraph 4388 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5600.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5600.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4389 ---
# Text: FSIS Dir 3900.1: TEMPORARY DUTY TRAVEL UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5610.1 Revision 1 6/29/18 CONSUMER COMPLAINT MONITORING SYSTEM I. PURPOSE This directive provides instructions on how to input, manage, and investigate comp...
# Keywords: fsis, temporary, duty, complaint, ccms, consumer, ophs
# Phrases: Consumer Complaint Monitoring System, Implement the Consumer Complaint Monitoring System, The FSIS Office of Public Health Science, Applied Epidemiology Staff, Food and Nutrition Service, entered into ccms, primary complaint type
# Acronyms: FSIS, TEMPORARY, DUTY, TRAVEL, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, CONSUMER, COMPLAINT, MONITORING, SYSTEM, PURPOSE, CCMS, II, CANCELLATION, III, BACKGROUND, OPHS, AES, IV, TYPES, COMPLAINTS, FNS, FDA, DISTRIBUTION, OPI, OPPD, USDA, NS, NOTE, FSS, OIEA, CID, IR, FIMS, EMC, OFO, DM, RECEIVING, COMPLAI, NTS, OPACE, VI, ENTERING, INTO, DO, VII, CONSIDERATIONS, INTAKE, VIII, EVALUATION, PHIS, MOI, IX, FOLLOW, UP, INTERVIEWS, POSSIBLE, OUTCOMES, AFTER, IIC, RMTAD, OPH, XI, COORDINATION, XII, RESPONSIBILITIES, DISTRICT, DURING, AN, INVESTIGATION, EIAO, XIII, PROCEDURES, SUBMITTING, PRODUCT, SAMPLES, TO, LABORATORY, ANALYSIS
#
# --- Paragraph 4390 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5610.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5610.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4391 ---
# Text: FSIS Dir 4200.2: NEW EMPLOYEE ORIENTATION - REVISION 1 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5620.1 Rev.1 7/22/14 DISTRIBUTION: Electronic OPI: OPPD USING askFSIS I. PURPOSE A. This directive provides instruction to inspection progra...
# Keywords: fsis, new, employee, question, questions, askfsis, application
# Phrases: Electronic OPI, Office of Policy and Program Development, The OPPD, International Relations and Strategic Planning Staff, Export Coordination and Policy Development Staff, posted public viewing, used when asking
# Acronyms: FSIS, NEW, EMPLOYEE, ORIENTATION, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, DISTRIBUTION, OPI, OPPD, USING, PURPOSE, IPP, IRSPS, IECPDS, RIMS, LPDS, PDS, USDA, KEY, POINTS, II, CANCELLATION, III, BACKGROUND, NOTE, IV, APPLICATION, LOGIN, CREATE, AN, ACCOUNT, VI, SEARCHING, ONLINE, KNOWLEDGE, BASE, O157, H7, VII, SUBMITTING, QUESTIONS, THROUGH, HACCP, NOIE, IAO, VIII, PROVIDING, FEEDBACK, IX, MANAGING, MY, TAB, HELP, AB, XI, LOG, OUT, XII, DATA, ANALYSIS, XIII, QUESTION, ATTACHMENT, PRODUCT, CATEGORY, OPTION, INFORMATION, SUB, MPI, EIAO, PHIS, SIP, EXPORT, IMPORT, LABELING, FDA, GMO, RTE, NRTE
#
# --- Paragraph 4392 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5620.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5620.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4393 ---
# Text: FSIS Dir 4271.2: PRE-TAX PARKING BENEFIT PROGRAM FOR NON-BARGAINING UNIT EMPLOYEES - REVISION 1 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5710.1 Rev. 1 6/1/16 DESIGNATION OF A STATE OR INDIVIDUAL STATE -INSPECTED ESTABLISHMENT FOR FSIS I...
# Keywords: fsis, pre-tax, parking, state, establishment, inspection, program
# Phrases: Office of Field Operations, District Managers, Office of Investigations, Enforcement and Audit, Federal State Audit Branch, state program officials, corrective action plan
# Acronyms: FSIS, PRE-TAX, PARKING, BENEFIT, PROGRAM, NON-BARGAINING, UNIT, EMPLOYEES, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, DESIGNATION, STATE, OR, INDIVIDUAL, INSPECTED, ESTABLISHMENT, CHAPTER, GENERAL, PURPOSE, OFO, OIEA, FSAB, OOEET, OPPD, IS, LPDS, OCHRO, OCIO, OCFO, OPHS, OPACE, MPI, KEY, POINTS, NOTE, CIS, DISTRIBUTION, OPI, II, CANCELLATION, III, BACKGROUND, FMIA, PPIA, HMSA, CFR, PROCESS, VOLUNTARY, USDA, AA, LQAS, CAUSE, HACCP, IEA, ODIFP, AN, IV, TRANSFER, ESTABLISHMENTS, CUSTOM, EXEMPT, OPERATIONS, TO, FEDERAL, DO, COORDINATION, OPD, RMPS, OM, HRO, EALS, DM, ELD, PHIS, IPP, INSTRUCTIONS, FLS
#
# --- Paragraph 4394 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5710.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5710.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4395 ---
# Text: FSIS Dir 4280.1: STUDENT EMPLOYMENT PROGRAM UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5720.2, Revision 3 11/16/04 STATE COOPERATIVE INSPECTION PROGRAMS I. PURPOSE The purpose of this directive is to articu late the policy and procedures ...
# Keywords: fsis, student, employment, state, program, inspection, federal
# Phrases: Food Safety and Inspection Service, State Cooperative Inspection Programs, Federal Meat Inspection Act, Poultry Products Inspection Act, Egg Products Inspection Act, state cooperative inspection, cooperative inspection program
# Acronyms: FSIS, STUDENT, EMPLOYMENT, PROGRAM, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, STATE, COOPERATIVE, PROGRAMS, PURPOSE, FSI, II, CANCELLATION, III, REASON, REISSUANCE, IV, REFERENCES, FMI, PPIA, EPI, VI, CFR, OPI, OPPED, DISTRIBUTION, TRA, ABB, TSC, PART, STATE-FEDERAL, BACKGROUND, MIA, FMIA, DEVELOPING, NEW, AGREEMENT, SELF-ASSESSMENT, COMPONENTS, HACCP, USDA, REPORT, REVIEW, CERTIFICATION, OPEER, FS, IS, OFO, VII, COOPERATION, VIII, DESIGNATION, TALMADGE-AIKEN, EPIA, NOTE, OOPERATIVE, DM
#
# --- Paragraph 4396 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5720.2.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5720.2.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4397 ---
# Text: FSIS Dir 4300.1: ENSURING THAT INSPECTION PROGRAM PERSONNEL HAVE PROPER TRAINING TO COVER WORK ASSIGNMENTS - REVISION 1 DISTRIBUTION: Electronic OPI: OPPD UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5730.1 Revision 1 6/21/23 RESPONSIBILITI...
# Keywords: fsis, ensuring, inspection, establishment, products, liaison, food
# Phrases: Electronic OPI, Food and Drug Administration, Memorandum of Understanding, Adds FSIS, Dual Jurisdiction Establishments, fsis headquarter liaison, meat poultry food
# Acronyms: FSIS, ENSURING, INSPECTION, PROGRAM, PERSONNEL, PROPER, TRAINING, TO, COVER, WORK, ASSIGNMENTS, REVISION, DISTRIBUTION, OPI, OPPD, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, SERVICE, WASHINGTON, DC, DIRECTIVE, RESPONSIBILITIES, IN, DUAL, JURISDICTION, ESTABLISHMENTS, PURPOSE, IPP, FDA, DJE, FSI, MOU, FS, IS, KEYPOINTS, II, CANCELLATION, III, BACKGROUND, NOTE, DO, WGS, USDA, IV, CFR, SPS, SOP, HACCP, DISTRICT, OFFICE, RESPONSIBILIT, IES, OFO, RMTAD, PHRE, VI, HEADQUA, RTERS, LIAISON, VII, QUESTIONS
#
# --- Paragraph 4398 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5730.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5730.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4399 ---
# Text: FSIS Dir 4300.1: REASSIGNMENT OF FOOD INSPECTORS AND CONSUMER SAFETY INSPECTORS IN WORK REDUCTION SITUATIONS - REVISION 1 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5720.3 Revision 2 11/10/16 METHODOLOGY FOR PERFORMING SCHEDULED AND TARGE...
# Keywords: fsis, reassignment, of, state, program, review, inspection
# Phrases: State Meat and Poultry Inspection, State MPI, State Audit Branch, Office of Investigation, Laboratory Quality Assurance Staff, state program officials, that state program
# Acronyms: FSIS, REASSIGNMENT, OF, FOOD, INSPECTORS, CONSUMER, SAFETY, IN, WORK, REDUCTION, SITUATIONS, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTURE, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, METHODOLOGY, PERFORMING, SCHEDULED, TARGETED, REVIEWS, STATE, MEAT, POULTRY, PROGRAMS, PU, RPO, SE, MPI, FSAB, OIEA, LQAS, OPHS, CRS, OA, FRAS, OCFO, KEY, POINTS, OTE, II, ANCELLATI, ON, SIS, III, ACKGROUN, FMIA, PPIA, PIA, DI, STRIBUTION, OPI, OPPD, HMSA, IV, REVIEW, CRITERIA, STEC, O157, O26, O45, O103, O111, O121, O145, RTE, USDA, CFR, ANNUAL, SELF, ASSESSMENT, NOTE, PT, FFY, OFO, SF, VI, ON-SITE, VII, ID, HACCP, VIII, CAR, IX, LEP, PI
#
# --- Paragraph 4400 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5720.3.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5720.3.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4401 ---
# Text: FSIS Dir 4300.5: DETAILS OF PERSONNEL - REVISION 3 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 5740.1 9/27/12 COOPERATIVE I NTERSTATE SHIPMENT PROGRAM CHAPTER I-GENERAL I. PURPOSE This directive describes the procedu res that FSIS personne...
# Keywords: fsis, details, of, state, program, establishment, establishments
# Phrases: Cooperative Interstate Shipment, State for, Roles of the Office of F, Federal Meat Inspection Act, Poultry Products Inspection Act, verify that state, meat poultry products
# Acronyms: FSIS, DETAILS, OF, PERSONNEL, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, COOPERATIVE, NTERSTATE, SHIPMENT, PROGRAM, CHAPTER, GENERAL, PURPOSE, CIS, KEY, POINTS, OFO, II, RESERVED, III, IV, REFERENCES, FMIA, PPIA, CFR, DISTRIBUTION, OPI, OPPD, BACKGROUND, XI, MPI, EVALUATING, STATE, REQUEST, TO, PARTICIPATE, IN, ENTERING, INTO, AN, AGREEMENT, RECEIPT, DISTRICT, MANAGER, DM, COORDINATOR, RESPONSIBILITIES, DO, HQ, EARO, NOTE, VERIFYING, AT, LEAST, EQUAL, MEAT, OR, POU, LTRY, OPEER, FSAB, ME, ETS, EACH, ELEMENT, IS, RMPS, OCIO, PHIS, PBIS, ISO, AOAC, ALACC, OPHS, LQAD, QA, MD, RAD, PARTICIPATION, OOEET, SELECTING, ESTABLISHMENTS, ROLE, ESTABL, ISHMENTS, SEC, FLS, LPDD, EST, ABLISHMENTS, MOI, HACCP, RTE
#
# --- Paragraph 4402 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5740.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/5740.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4403 ---
# Text: FSIS Dir 4300.6: TEMPORARY PROMOTIONS AND DETAILS UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 6000.1 Revision 1 8/3/06 RESPONSIBILITIES RELATED TO FOREIGN ANIMAL DISEASES (FADs) AND REPORTABLE CONDITIONS I. PURPOSE This directive provides ...
# Keywords: fsis, temporary, promotions, diseases, conditions, animal, disease
# Phrases: Public Health Veterinarians, List A and List B, World Organization for Animal Health, United States, Outbreaks of, fsis directive 6000, fsis 4300 temporary
# Acronyms: FSIS, TEMPORARY, PROMOTIONS, DETAILS, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, RESPONSIBILITIES, RELATED, TO, FOREIGN, ANIMAL, DISEASES, REPORTABLE, CONDITIONS, PURPOSE, II, CANCELLATION, III, REASON, REISSUANCE, IV, REFERENCES, CFR, BACKGROUND, DISTRIBUTION, OPI, OPPED, TRA, TSC, USDA, APHIS, FAD, OIE, VI, DO, VII, CNS, PHV, AVIC, SAHO
#
# --- Paragraph 4404 ---
# Text: FSIS Dir 4300.8: RECRUITMENT: RELOCATION: AND RETENTION INCENTIVES - REVISION 1 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 6020.1 Rev. 1 9/21/16 ENHANCED INSPECTION OF POULTRY IN RESPONSE TO A NOTIFICATION OF A HIGHLY PATHOGENIC AVIAN INF...
# Keywords: fsis, recruitment, relocation, hpai, poultry, aphis, inspection
# Phrases: Highly Pathogenic Avian Influenza, Enhanced Inspection of Poultry Related, Notification of, New Poultry Inspection System, Animal and Plant Health Inspection Service, fsis directive 6020, directive 6020 enhanced
# Acronyms: FSIS, RECRUITMENT, RELOCATION, RETENTION, INCENTIVES, REVISION, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, ENHANCED, POULTRY, IN, RESPONSE, TO, NOTIFICATION, HIGHLY, PATHOGENIC, AVIAN, INFLUENZA, OUTBREAK, NOTE, PURPOSE, IPP, HPAI, NPIS, KEYPOINTS, USDA, APHIS, DO, II, CANCELLATION, DISTRIBUTION, OPI, OPPD, III, BACKGROUND, MAC, IV, HEADQUARTERSAND, RESPONSIBILITIES, DURING, AN, IR, FIMS, GIS, ODIFP, SPRS, AT, ESTABLISHMENTS, AFTER, RECEIVING, CONFIRMED, POSITIVE, SAHO, SAH, APHI, VI, VII, ENHANCE, ANTE, MORT, EM, INSPECTIO, RESPON, SE, HP, AI, VS, VS1, PHV, POST, MORTEM, CFR, VIII, DOCUMENTATION, IX, SAMPLE, COLLECTION, EMC, HYGIENE, BIOSECURITY, PRACTICES, XI, QUESTIONS
#
# --- Paragraph 4405 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/6020.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/6020.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4406 ---
# Text: FSIS Dir 4304.1: EMPLOYMENT OF EXPERTS AND CONSULTANTS - REVISION 2 UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC 6030.1, 8/10/05 FSIS DIRECTIVE Revision 1 RELIGIOUS EXEMPTION FOR THE SLAUGHT ER AND PROCESSING OF POULTRY I. PURPOSE This directive provides ...
# Keywords: fsis, employment, of, poultry, religious, exemption, inspection
# Phrases: Exemption Certific, Confucian Style Poultry, Islamic Style Poultry, Exemption Certif, Buddhist Style Poultry, under religious exemption, inspection program personnel
# Acronyms: FSIS, EMPLOYMENT, OF, EXPERTS, CONSULTANTS, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, RELIGIOUS, EXEMPTION, SLAUGHT, ER, PROCESSING, POULTRY, PURPOSE, II, CANCELLATIONS, III, REASON, REISSUANCE, IV, REFERENCES, PPIA, CFR, DISTRIBUTION, OPI, OPPED, ABB, PRD, FORMS, ABBREVIATIONS, DO, HRI, LCPS, PHV, TSC, VI, BACKGROUND, VII, DISTRICT, OFFI, CE, RESPONSIBILITIES, IIC, NOTE, VIII, PROGRAM, PERSONNEL, VERIFICATION, HACCP, IX, DOCUMENTATION, ENFORCEMENT, NR, LABELING, REQUIREMENTS, MANDATORY, OPTIONAL, USDA, FR
#
# --- Paragraph 4407 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/6030.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/6030.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4408 ---
# Text: FSIS Dir 4306.1: EMPLOYMENT OF PEOPLE WITH DISABILITIES (INCLUDING DISABLED VETERANS) - REVISION 5 UNITED STATES DEPARTMENT OF AGRICULTUR E FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC 6090.1 7/24/19 FSIS DIRECTIVE FIREARMS SAFETY IN OFFICIAL LIVESTOCK ESTABLISHMENTS I. PURPOSE This directive p...
# Keywords: fsis, employment, of, safety, firearms, employees, directive
# Phrases: Safety and Health Act of, Executive Order, Occupational Safety and Health Programs for Federal Employees, Basic Program Elements for Federal Employees, Occupational Safety and Health Administration, occupational safety health, fsis 4306 employment
# Acronyms: FSIS, EMPLOYMENT, OF, PEOPLE, DISABILITIES, INCLUDING, DISABLED, VETERANS, REVISION, UNITED, STATES, DEPARTMENT, AGRICULTUR, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, FIREARMS, IN, OFFICIAL, LIVESTOCK, ESTABLISHMENTS, PURPOSE, IPP, IIC, II, BACKGROUND, CFR, OSHA, III, PROCEDURES, MOI, DISTRIBUTION, OPI, OPPD, IV, QUESTIONS
#
# --- Paragraph 4409 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/6090.1.pdf https://www.fsis.usda.gov/sites/default/files/media_file/2020-07/6090.1.pdf::https://www.acquisition.gov/sites/default/files/page_file_uploa...
# Keywords: https, sites, default, files, acquisition, page_file_uploads, far-companion
# Phrases: sites default files, https acquisition sites, acquisition sites default, default files page_file_uploads, files page_file_uploads far-companion, https fsis usda, fsis usda sites
# Acronyms: (none)
#
# --- Paragraph 4410 ---
# Text: FSIS Dir 4306.2: REASONABLE ACCOMMODATION AND ACCESSIBILITY FOR PEOPLE WITH DISABILITIES UNITED STATES DEPARTMENT OF AGRICULTURE FOOD SAFETY AND INSPECTION SERVICE WASHINGTON, DC FSIS DIRECTIVE 6100.1 Rev 3 5/7/20 ANTE -MORTEM LIVESTOCK INSPECTION I. PURPOSE This directive provides instructions to i...
# Keywords: fsis, reasonable, accommodation, livestock, establishment, inspection, slaughter
# Phrases: Public Health Information System, Livestock Inspection, Federal Meat Inspection Act, Public Health Veterinarian, Consumer Safety Inspector, ante- mortem inspection, ante -mortem inspection
# Acronyms: FSIS, REASONABLE, ACCOMMODATION, ACCESSIBILITY, PEOPLE, DISABILITIES, UNITED, STATES, DEPARTMENT, OF, AGRICULTURE, FOOD, SAFETY, INSPECTION, SERVICE, WASHINGTON, DC, DIRECTIVE, ANTE, MORTEM, LIVESTOCK, PURPOSE, IPP, US, PHIS, KEY, POINTS, II, CANCELLATIONS, III, BACKGROUND, CFR, PHV, CSI, FI, FR, DISTRIBUTION, OPI, OPPD, IV, PERSONAL, VERIFICATION, OFFERED, SLAUGHTER, NSIS, NOTE, FLS, XV, VI, PROCEDURES, NUMBER, IIC, NR, VII, IDENTIFYING, CONTROLLING, ACCOUNTING, DURING, VIII, DETERMINING, SLAUGHTERED, AT, AN, ESTABLISHMENT, RECEIVED, HATS, PM, IX, STEPS, FOLLOW, WHEN, CONDUCTING, INSPECTIO, PDS, DO, HACCP, MOI, VERIFYING, VOLUNTARY, SEGREGATION, BEFORE, SWINE, SHEEP, APHIS, VS, XI, RELATED, TO, SUSPECT, USDA, XII, DISPOSITION, CATTLE, BECOME, RECUMBENT, OR, NON, AMBULATORY, DISABLED, AFTER, PASSING, EXAMPLES, XIII, CONDEMNED
#
# --- Paragraph 4411 ---
# ...
# Keywords: usda, ocio, cor, contractor, assessment, contract, government, uma-mandatory, naming, transition-in
# Phrases: Acquisitions Development Project List, Cybersecurity Contract Consolidation, New Assessment and Authorization Performance Work Statement Draft, Deliverable Submission, Inspection and Acceptance, after call order, usda ocio acquisitions
# Acronyms: USDA, OCIO, COR, IT, UMA, UNC, CO, PWS, CMP, WBS, WAR, CPR, GFI, BPA, IMS, CWBS, NLT, SAP, CAP, CSAM, SRTM, SAR, SO, AO, RMF, SOP, POA, NDA
#
# --- Paragraph 5157 ---
# Text: USDA OCIO Acquisitions Development Project List: Cybersecurity Contract Consolidation - New Assessment and Authorization Performance Work Statement Draft 20251024 - 16. PERFORMANCE REQUIREMENT SUMMARY The Performance Requirement Summary (PRS) is used to indicate how the Government will measure the C...
# Keywords: usda, ocio, performance, contractor, personnel, contractual, deliverables, receptiveness, marginally, onboarded
# Phrases: Acquisitions Development Project List, Cybersecurity Contract Consolidation, New Assessment and Authorization Performance Work Statement Draft, The Performance Requirement Summary, Performance and, free grammatical errors, deliverables with errors
# Acronyms: USDA, OCIO, PERFORMANCE, REQUIREMENT, SUMMARY, PRS, BPA, GSA, MAS, PWS, CPARS, WBS, COR
#
# --- Paragraph 5158 ---
# Text: ECQ 1.3: Leading Change Flexibility Executive Core Qualifications Skip to page navigation An official website of the United States government Here's how you know Here's how you know Official websites use .gov A .gov website belongs to an official government organization in the United States. Secure ...
# Keywords: ecq, https, opm, submenu, toggle, management, executive, 4020-250-1
# Phrases: Leading Change Flexibility Executive Core Qualifications Skip, United States, Lock A, Submit Sections About Toggle, Our Agency Who We Are Our Work Mission, submenu close menu, executive core qualifications
# Acronyms: ECQ, HTTPS, OPM, FY, CHCO, FEHB, FEDVIP, CSRS, FERS, FEGLI, FWPR, HCR, CBA, ARPA, SES, RIF, HR, II, SME, USAJOBS, CDP, FOIA, FEAR, USA, USDA
#
# --- Paragraph 5159 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf OPM USDA Office of the Chief Financial Officer, Internal Control Division https://www.opm.gov/policy-data-oversight/senior-executive-service/executive-core-qualifications https://www.opm.gov/policy-data-oversight/sen...
# Keywords: opm, usda, https, acquisition, sites, default, files, executive-core-qualifications, senior-executive-service
# Phrases: Office of the Chief Financial Officer, Internal Control Division, https acquisition sites, acquisition sites default, sites default files, default files page_file_uploads, files page_file_uploads far-companion
# Acronyms: OPM, USDA
#
# --- Paragraph 5160 ---
# Text: USDA IT Dir 3540-003: Security Assessment and Authorization This Departmental Regulation (DR) establishes the policy of the United States Department of Agriculture (USDA) for meeting the laws, regulations, and standards of a comprehensive information security awareness and training program. b. This ...
# Keywords: usda, it, dr, security, information, awareness, training
# Phrases: Security Assessment and Authorization This Departmental Regulation, United States Department of Agriculture, This DR, Office of Management and Budget, National Institute of Standards and Technology, security awareness training, information security awareness
# Acronyms: USDA, IT, DR, OMB, NIST, FISMA, STRATUS, FY
#
# --- Paragraph 5161 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf USDA Office of the Chief Information Officer– Client Experience Center https://www.usda.gov/directives/dr-3540-003 https://www.usda.gov/directives/dr-3540-003::https://www.acquisition.gov/sites/default/files/page_fil...
# Keywords: usda, https, acquisition, sites, default, files, page_file_uploads, dr-3540-003
# Phrases: Office of the Chief Information Officer, Client Experience Center, https acquisition sites, acquisition sites default, sites default files, default files page_file_uploads, files page_file_uploads far-companion
# Acronyms: USDA
#
# --- Paragraph 5162 ---
# Text: ECQ 1.5: Leading Change - Strategic Thinking Executive Core Qualifications Skip to page navigation An official website of the United States government Here's how you know Here's how you know Official websites use .gov A .gov website belongs to an official government organization in the United States...
# Keywords: ecq, https, opm, submenu, toggle, management, executive
# Phrases: Leading Change, Strategic Thinking Executive Core Qualifications Skip, United States, Lock A, Submit Sections About Toggle, submenu close menu, executive core qualifications
# Acronyms: ECQ, HTTPS, OPM, FY, CHCO, FEHB, FEDVIP, CSRS, FERS, FEGLI, FWPR, HCR, CBA, ARPA, SES, RIF, HR, II, SME, USAJOBS, CDP, FOIA, FEAR, USA, USDA, DM
#
# --- Paragraph 5163 ---
# Text: USDA DR 3440-003, Controlled Unclassified Information (CUI) Program This Departmental Regulation (DR) establishes the United States Department of Agriculture (USDA) privacy policy, provides the impetus and foundations for the Privacy Program, and guides the development of associated processes and pr...
# Keywords: usda, dr, cui, information, program, privacy, policy, 3440-003
# Phrases: Controlled Unclassified Information, Program This Departmental Regulation, United States Department of Agriculture, Privacy Program, Departmental Privacy Program and, usda 3440-003 controlled, 3440-003 controlled unclassified
# Acronyms: USDA, DR, CUI, PII, OMB, RM
#
# --- Paragraph 5164 ---
# Text: USDA DR 3575-004, Information Technology Security Baselines and Security Control Tailoring This Departmental Regulation (DR) establishes the United States Department of Agriculture (USDA) Information Technology (IT) Security Controls Baselines for information systems. b. The USDA derives IT security...
# Keywords: usda, dr, it, security, information, baselines, control, 3575-004
# Phrases: Information Technology Security Baselines and Security Control Tailoring This Departmental Regulation, United States Department of Agriculture, Information Technology, Security Controls Baselines for, The USDA, information technology security, usda 3575-004 information
# Acronyms: USDA, DR, IT, ITSB, NIST, SP, FAR, FC
#
# --- Paragraph 5165 ---
# Text: USDA 2025 Annual Evaluation Plan 1.3 - Survey of Local Irrigation Systems (NASS) How and to what extent do local irrigation decisions have an impact on drought resilience? Survey conducted by NASS under the guidance of USDA's Economic Research Service is intended to provide a nationally representati...
# Keywords: usda, nass, irrigation, 2025, annual, evaluation, plan, irrigated, water-supply, water-delivery
# Phrases: Annual Evaluation Plan, Survey of Local Irrigation Systems, How and, Economic Research Service, Regulatory Development and Review USDA Directives USDA, usda 2025 annual, 2025 annual evaluation
# Acronyms: USDA, NASS
#
# --- Paragraph 5166 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf OMB OPM 2026, agencies, agency, allow, are, continue, effort, ensure, enterprise, federal, fiscal, following, fy, government, implementation, information, management, omb, performance, provides, requirements, resourc...
# Keywords: omb, opm, https, acquisition, sites, default, files, m-25-04-fiscal-year-2025-guidance-on-federal-information-security-and-privacy-management-requirements, bidenwhitehouse
# Phrases: https acquisition sites, acquisition sites default, sites default files, default files page_file_uploads, files page_file_uploads far-companion, https bidenwhitehouse archives, bidenwhitehouse archives wp-content
# Acronyms: OMB, OPM
#
# --- Paragraph 5167 ---
# Text: OMB-OPM HR 2.0 Memo 12-10-2025: Transition to a single Core human capital management (HCM) platform Over the next two years, led by OMB and OPM, the Federal Government will transition to a single Core HCM platform, which will encompass the following functions: personnel action processing, employee s...
# Keywords: omb-opm, hr, hcm, core, transition, single, system, decommissioning
# Phrases: Over the, Federal Government, Core HCM, The Core HCM, Federal HR IT, omb-opm memo 12-10-2025, transition single core
# Acronyms: OMB-OPM, HR, HCM, OMB, OPM, IT, FY, EHRI, USC, FISMA, II
#
# --- Paragraph 5168 ---
# Text: https://www.acquisition.gov/sites/default/files/page_file_uploads/far-companion.pdf OPM OMB across, agencies, are, budget, bureaucratic, consolidate, data, duplication, duplicative, efficiency, eliminate, entire, federal, goal, government, governmentwide, human, instead, is, leading, management, mor...
# Keywords: opm, omb, usopm, https, acquisition, sites, default
# Phrases: https acquisition sites, acquisition sites default, sites default files, default files page_file_uploads, files page_file_uploads far-companion, https content govdelivery, content govdelivery attachments
# Acronyms: OPM, OMB, USOPM, HR
#
# --- Paragraph 5169 ---
# Text: USDA IT Directives:DR3300-001-I Internet (072919) The purpose of this memorandum is to provide implementation guidance for the Federal Information Technology Acquisition Reform Act (FITARA) 1 and related information technology (IT) management practices. Background FITARA was enacted on December 19,2...
# Keywords: usda, it, dr3300-001-i, chief, officer, directives, guidance
# Phrases: Federal Information Technology Acquisition Reform Act, Background FITARA, Agency Chief Information Officer, Authority Enhancements, Enhanced Transparency and Improved Risk Management, usda directives dr3300-001-i, directives dr3300-001-i internet
# Acronyms: USDA, IT, DR3300-001-I, FITARA, CIO, OMB, CFO, CHCO, CAO, ASAM, COO, OMB-OPM, HR
#
# --- Paragraph 5170 ---
# Text: OMB-OPM HR 2.0 Memo 12-10-2025: Core human capital management ("Core HCM") systems For too long, the Federal Government has lacked what is taken for granted at any other organization-a single system of record for personnel management. Instead, the Federal Government spends an inordinate amount each ...
# Keywords: omb-opm, hr, hcm, core, federal, management, systems, inordinate, organization-a, eliminat
# Phrases: Core HCM, Federal Government, The Federal Government, Outdated and, President Trump, omb-opm memo 12-10-2025, core human capital
# Acronyms: OMB-OPM, HR, HCM, IT, OMB, OPM, FY
#
# --- Paragraph 5171 ---
# Text: USDA 2025 Annual Evaluation Plan 1.7 - National Program Assessments (Agricultural Research Service (ARS)) To what extent did this national program accomplish its goals and objectives as specified in the national program action plan? The national program assessments are conducted every five years and...
# Keywords: usda, ars, dr, national, program, plan, evaluation, 1110-002
# Phrases: Annual Evaluation Plan, National Program Assessments, Agricultural Research Service, Responsibility for Internal Control USDA Directives USDA, Annual Evaluation Plan USDA, usda 2025 annual, 2025 annual evaluation
# Acronyms: USDA, ARS, DR
#
# --- Paragraph 5172 ---
# Text: USDA 3-10-2025 Memo on STRATUS Cloud Solution Vehicles - Requirements Language This memorandum transmits the Office of the Chief Information Officer's (OCIO) Cloud Computing Policy and associated information technology (IT) contract requirements language for cloud computing at the U.S. Department of...
# Keywords: usda, stratus, ocio, cloud, 3-10-2025, memo, computing
# Phrases: Cloud Solution Vehicles, Requirements Language This, Office of the Chief Information Officer, Cloud Computing Policy and, Department of Agriculture, usda 3-10-2025 memo, 3-10-2025 memo stratus
# Acronyms: USDA, STRATUS, OCIO, IT, DR3650-001, GAO, DR, ECVM, CIO, SP, FY2024, OMB
#
# --- Paragraph 5173 ---
# Text: https://www.usda.gov/sites/default/files/documents/usda_it_strategic_plan_final.pdf USDA USDA
# Keywords: usda, https, sites, default, files, documents, usda_it_strategic_plan_final
# Phrases: (none)
# Acronyms: USDA
#
# --- Paragraph 5174 ---
# Text: https://www.usda.gov/directives/dr-3650-001 USDA USDA
# Keywords: usda, https, directives, dr-3650-001
# Phrases: (none)
# Acronyms: USDA
#
# --- Paragraph 5175 ---
# Text: https://www.whitehouse.gov/wp-content/uploads/legacy_drupal_files/omb/memoranda/2015/m-15-14.pdf USDA
# Keywords: usda, https, whitehouse, wp-content, uploads, legacy_drupal_files, memoranda
# Phrases: (none)
# Acronyms: USDA
#
# --- Paragraph 5176 ---
# Text: https://www.whitehouse.gov/wp-content/uploads/legacy_drupal_files/omb/memoranda/2012/m-12-10_1.pdf USDA
# Keywords: usda, https, whitehouse, wp-content, uploads, legacy_drupal_files, memoranda, m-12-10_1
# Phrases: (none)
# Acronyms: USDA
#
# --- Paragraph 5177 ---
# Text: https://www.whitehouse.gov/wp-content/uploads/legacy_drupal_files/omb/memoranda/2014/m-14-03.pdf USDA
# Keywords: usda, https, whitehouse, wp-content, uploads, legacy_drupal_files, memoranda
# Phrases: (none)
# Acronyms: USDA
#
# --- Paragraph 5178 ---
# Text: https://www.whitehouse.gov/wp-content/uploads/2017/11/M-18-12.pdf USDA
# Keywords: usda, https, whitehouse, wp-content, uploads, 2017, m-18-12
# Phrases: (none)
# Acronyms: USDA
#
# --- Paragraph 5179 ---
# Text: https://assets.performance.gov/PMA/Biden-Harris_Management_Agenda_Vision_11-18.pdf USDA
# Keywords: pma, usda, https, assets, performance, biden-harris_management_agenda_vision_11-18
# Phrases: (none)
# Acronyms: PMA, USDA
#
# --- Paragraph 5180 ---
# Text: USDA 3-10-2025 Memo on STRATUS Cloud Solution Vehicles - supporting the Federal Information Technology Acquisition Reform Act (FITARA) GAO guidance to USDA from GAO Report 24-106137 addresses gaps in USDA's Cloud Computing and acquisition practices supporting Federal Information Technology Acquisiti...
# Keywords: usda, stratus, fitara, 3-10-2025, memo, cloud, acquisition, collaborated, 24-106137
# Phrases: Cloud Solution Vehicles, Federal Information Technology Acquisition Reform Act, Cloud Computing and, Service Level Agreement, High Value Asset, usda 3-10-2025 memo, 3-10-2025 memo stratus
# Acronyms: USDA, STRATUS, FITARA, GAO, SLA, HVA, OCIO, DISC, OCP, IT, OMB
#
# --- Paragraph 5181 ---
# Text: USDA 3-10-2025 Memo on STRATUS Cloud Solution Vehicles - Enterprise Cloud Vendor Management (ECVM) Consistent with the Trump Administration goal of avoiding wasteful spending, STRATUS will utilize the Enterprise Cloud Vendor Management (ECVM) Program to reduce costs and better allocate resources and...
# Keywords: usda, stratus, ecvm, cloud, management, 3-10-2025, memo, finops
# Phrases: Cloud Solution Vehicles, Enterprise Cloud Vendor Management, Trump Administration, The ECVM, Chief Information Officer USDA OCIO Acquisitions Development Project List, usda 3-10-2025 memo, 3-10-2025 memo stratus
# Acronyms: USDA, STRATUS, ECVM, IT, AI, OCIO, OMB
#
# --- Paragraph 5182 ---
# Text: USDA 3-10-2025 Memo on STRATUS Cloud Solution Vehicles - Basic Ordering Agreements USDA STRATUS consists of a set of Basic Ordering Agreements designed to provide an acquisition solution for all cloud solution requirements across USDA. This includes compute and storage services, integration, develop...
# Keywords: usda, stratus, dr3650-001, cloud, 3-10-2025, solution, memo
# Phrases: Cloud Solution Vehicles, Basic Ordering Agreements USDA STRATUS, Basic Ordering Agreements, Cloud Computing Policy, Mission Areas, usda 3-10-2025 memo, 3-10-2025 memo stratus
# Acronyms: USDA, STRATUS, DR3650-001, CIO, OCIO, FY, IT, FITARA, OMB
#
# ================================================================================
#
# Step 6: Exporting results...
# CSV exported to: C:\Users\Kristen.Boucher\OneDrive - USDA\Desktop\Data Analysis\IVN\ivn\ivntest_keywords.csv
# JSON exported to: C:\Users\Kristen.Boucher\OneDrive - USDA\Desktop\Data Analysis\IVN\ivn\ivntest_keywords.json
#
# ================================================================================
# EXTRACTION COMPLETE!
# ================================================================================
